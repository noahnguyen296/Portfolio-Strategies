# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import statsmodels.api as sm
import datetime as dt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 1. IMPORTING MARKET, ASSETS AND FACTORS DATA

# %%
industry_raw = pd.read_excel('Industry_Portfolios.xlsx')
industry_raw = industry_raw.set_index('Date')
industry_raw.index = pd.to_datetime(industry_raw.index, format = '%Y%m')
industry_raw.index = industry_raw.index.to_period('M')
industry_raw.head(2)
# Out:
#          NoDur  Durbl  Manuf  Enrgy  HiTec  Telcm  Shops  Hlth  Utils  Other
# Date
# 2004-01   0.06  -1.07  -0.62   0.44   4.53   1.41   0.45  3.09   1.92   2.88
# 2004-02   4.25  -0.07   1.95   4.69  -2.92  -0.52   6.09  0.89   2.07   2.16

# %%
market_raw = pd.read_excel('Market_Portfolio.xlsx')
market_raw =  market_raw.set_index('Date')
market_raw.index = pd.to_datetime(market_raw.index, format = '%Y%m')
market_raw.index = market_raw.index.to_period('M')
market_raw.head(2)
# Out:
#          Market
# Date
# 2004-01    2.22
# 2004-02    1.46

# %%
ff_3 = pd.read_excel('Risk_Factors.xlsx')
ff_3 =  ff_3.set_index('Date')
ff_3.index = pd.to_datetime(ff_3.index, format = '%Y%m')
ff_3.index = ff_3.index.to_period('M')
ff_3.head()
# Out:
#            Rf  Rm-Rf   SMB   HML
# Date
# 2004-01  0.07   2.15  2.67  1.55
# 2004-02  0.06   1.40 -1.17  0.45
# 2004-03  0.09  -1.32  1.84  0.07
# 2004-04  0.08  -1.83 -2.59 -1.67
# 2004-05  0.06   1.17 -0.10 -0.33

# %%
df_merged = (ff_3.merge(market_raw, how = 'left', left_index = True, right_index = True)
             .merge(industry_raw, how = 'left', left_index = True, right_index = True))
df_merged.head()
# Out:
#            Rf  Rm-Rf   SMB   HML  Market  NoDur  Durbl  Manuf  Enrgy  HiTec  \
# Date
# 2004-01  0.07   2.15  2.67  1.55    2.22   0.06  -1.07  -0.62   0.44   4.53
# 2004-02  0.06   1.40 -1.17  0.45    1.46   4.25  -0.07   1.95   4.69  -2.92
# 2004-03  0.09  -1.32  1.84  0.07   -1.23  -0.09  -1.15  -0.27  -0.13  -2.55
# 2004-04  0.08  -1.83 -2.59 -1.67   -1.75   1.42   2.30  -0.17   2.52  -4.91
# 2004-05  0.06   1.17 -0.10 -0.33    1.23  -1.89  -1.64   1.61   0.39   4.85
#
#          Telcm  Shops  Hlth  Utils  Other
# Date
# 2004-01   1.41   0.45  3.09   1.92   2.88
# 2004-02  -0.52   6.09  0.89   2.07   2.16
# 2004-03  -2.07   0.29 -3.96   1.13  -0.63
# 2004-04  -0.48  -2.70  3.54  -3.55  -3.76
# 2004-05  -2.95   0.30 -0.42   1.28   1.86

# %% [markdown]
# ### 2. RUN FACTOR (INDEX MODEL)
# * Here we define a more comprehensive model compared to the classic CAPM models.
# * The output includes the cofficients of the CAPM model as well as those for the factor models.
# * Basically we can incorporate unlimited factors to run this developed function.

# %% [markdown]
# ### 2.1. Get full model results

# %%
def factor_model_single(df: pd.DataFrame, asset_col: str, factors: list, rf_col: str = 'Rf', capm_factor: str = 'Market'):
    """
    Calculate the factor model (e.g., CAPM or multi-factor model) alpha and betas for a given asset.
    
    Parameters:
    - df (pd.DataFrame): DataFrame containing columns for asset returns, factors, and risk-free rates.
    - asset_col (str): The column name of the asset returns.
    - factors (list): List of factor column names (e.g., ['Market', 'SMB', 'HML']).
    - rf_col (str): The column name of the risk-free rates (default: 'Rf').
    - capm_factor (str): The column name for the CAPM market factor (default: 'Market').
    
    Returns:
    - dict: A dictionary containing CAPM Alpha, CAPM Beta, multi-factor alpha, betas for each factor, and the regression model summaries.
    """
    # Step 1: Calculate Excess Returns using the risk-free rate for the asset and each factor
    asset_excess_return = df[asset_col] - df[rf_col]
    factors_excess_return = df[factors].sub(df[rf_col], axis=0)
    capm_excess_return = df[capm_factor] - df[rf_col]
    
    # Step 2: Prepare Data for Regression
    data = pd.concat([asset_excess_return, factors_excess_return], axis=1).dropna()
    data.columns = ['Asset Excess Return'] + factors  # Rename columns for clarity
    
    # Step 3: Calculate CAPM Alpha and Beta (simple linear regression with the market factor)
    capm_data = pd.concat([asset_excess_return, capm_excess_return], axis=1).dropna()
    capm_data.columns = ['Asset Excess Return', 'Market Excess Return']
    
    X_capm = sm.add_constant(capm_data['Market Excess Return'])
    capm_model = sm.OLS(capm_data['Asset Excess Return'], X_capm).fit()
    capm_alpha = capm_model.params['const']  # CAPM Alpha
    capm_beta = capm_model.params['Market Excess Return']  # CAPM Beta

    # Step 4: Run the Multi-Factor Regression
    X_multi = sm.add_constant(data[factors])  # Predictor variables include the factors
    y = data['Asset Excess Return']           # Response variable is the asset's excess return
    
    multi_factor_model = sm.OLS(y, X_multi).fit()
    
    # Step 5: Extract Alpha (intercept) and Betas (slopes for each factor) from multi-factor model
    ff_alpha = multi_factor_model.params['const']
    betas = {factor: multi_factor_model.params[factor] for factor in factors}
    
    # Return results in a dictionary, including CAPM Alpha, CAPM Beta, and multi-factor model details
    return {
        'capm_alpha': round(capm_alpha, 4),
        'capm_beta': round(capm_beta, 4),
        'ff_alpha': round(ff_alpha, 4),
        'betas': {factor: round(betas[factor], 4) for factor in betas},
        'capm_model_summary': capm_model.summary(),
        'multi_factor_model_summary': multi_factor_model.summary()
    }
    

# 2. Run factor (index) model for multiple assets
def factor_model_mult(df: pd.DataFrame, asset_cols: list, factors: list, rf_col: str = 'Rf', capm_factor: str = 'Market'):
    """
    Run factor models (e.g., CAPM or multi-factor models) for multiple assets.
    
    Parameters:
    - df (pd.DataFrame): DataFrame containing columns for multiple asset returns, factors, and risk-free rates.
    - asset_cols (list): List of column names corresponding to the asset returns.
    - factors (list): List of factor column names (e.g., ['Market', 'SMB', 'HML']).
    - rf_col (str): The column name of the risk-free rates (default: 'Rf').
    - capm_factor (str): The column name for the CAPM market factor (default: 'Market').
    
    Returns:
    - dict: A dictionary containing factor model results for each asset (CAPM alpha/beta, multi-factor alpha/betas, and model summaries).
    """
    results = {}
    
    # Loop through each asset column in the list and calculate the factor model
    for asset_col in asset_cols:
        # Calculate alphas and betas for each asset, including both CAPM and multi-factor results
        results[asset_col] = factor_model_single(df, asset_col, factors, rf_col=rf_col, capm_factor=capm_factor)
    
    return results

# %%
asset_cols =  industry_raw.columns
factors =  ['Rm-Rf', 'SMB', 'HML']
ff_3_model = factor_model_mult(df_merged/100, asset_cols, factors, rf_col = 'Rf')

# Divide by 100 because the data is represented as % already, hence this step might be useful dependently

# %%
ff_3_model
# Out:
# {'NoDur': {'capm_alpha': 0.0037,
#   'capm_beta': 0.6537,
#   'ff_alpha': 0.0045,
#   'betas': {'Rm-Rf': 0.7108, 'SMB': -0.2314, 'HML': -0.0202},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.719
#   Model:                             OLS   Adj. R-squared:                  0.716
#   Method:                  Least Squares   F-statistic:                     301.4
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           2.77e-34
#   Time:                         11:00:55   Log-Likelihood:                 313.64
#   No. Observations:                  120   AIC:                            -623.3
#   Df Residuals:                      118   BIC:                            -617.7
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0037      0.002      2.243      0.027       0.000       0.007
#   Market Excess Return     0.6537      0.038     17.361      0.000       0.579       0.728
#   ==============================================================================
#   Omnibus:                        3.877   Durbin-Watson:                   2.246
#   Prob(Omnibus):                  0.144   Jarque-Bera (JB):                3.912
#   Skew:                          -0.426   Prob(JB):                        0.141
#   Kurtosis:                       2.764   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.737
#   Model:                             OLS   Adj. R-squared:                  0.731
#   Method:                  Least Squares   F-statistic:                     108.6
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.53e-33
#   Time:                         11:00:55   Log-Likelihood:                 317.80
#   No. Observations:                  120   AIC:                            -627.6
#   Df Residuals:                      116   BIC:                            -616.5
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0045      0.002      2.786      0.006       0.001       0.008
#   Rm-Rf          0.7108      0.043     16.408      0.000       0.625       0.797
#   SMB           -0.2314      0.081     -2.853      0.005      -0.392      -0.071
#   HML           -0.0202      0.073     -0.278      0.781      -0.164       0.124
#   ==============================================================================
#   Omnibus:                        7.991   Durbin-Watson:                   2.230
#   Prob(Omnibus):                  0.018   Jarque-Bera (JB):                7.730
#   Skew:                          -0.601   Prob(JB):                       0.0210
#   Kurtosis:                       3.316   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Durbl': {'capm_alpha': -0.0042,
#   'capm_beta': 1.6494,
#   'ff_alpha': -0.0017,
#   'betas': {'Rm-Rf': 1.4418, 'SMB': 0.6515, 'HML': 0.2507},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.734
#   Model:                             OLS   Adj. R-squared:                  0.732
#   Method:                  Least Squares   F-statistic:                     326.1
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           9.32e-36
#   Time:                         11:00:55   Log-Likelihood:                 207.32
#   No. Observations:                  120   AIC:                            -410.6
#   Df Residuals:                      118   BIC:                            -405.1
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                   -0.0042      0.004     -1.045      0.298      -0.012       0.004
#   Market Excess Return     1.6494      0.091     18.059      0.000       1.469       1.830
#   ==============================================================================
#   Omnibus:                       70.256   Durbin-Watson:                   2.284
#   Prob(Omnibus):                  0.000   Jarque-Bera (JB):              614.503
#   Skew:                           1.740   Prob(JB):                    3.65e-134
#   Kurtosis:                      13.526   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.764
#   Model:                             OLS   Adj. R-squared:                  0.757
#   Method:                  Least Squares   F-statistic:                     124.9
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           3.60e-36
#   Time:                         11:00:55   Log-Likelihood:                 214.32
#   No. Observations:                  120   AIC:                            -420.6
#   Df Residuals:                      116   BIC:                            -409.5
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const         -0.0017      0.004     -0.448      0.655      -0.009       0.006
#   Rm-Rf          1.4418      0.103     14.049      0.000       1.239       1.645
#   SMB            0.6515      0.192      3.392      0.001       0.271       1.032
#   HML            0.2507      0.172      1.459      0.147      -0.090       0.591
#   ==============================================================================
#   Omnibus:                       56.513   Durbin-Watson:                   2.225
#   Prob(Omnibus):                  0.000   Jarque-Bera (JB):              371.290
#   Skew:                           1.401   Prob(JB):                     2.37e-81
#   Kurtosis:                      11.149   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Manuf': {'capm_alpha': 0.0016,
#   'capm_beta': 1.1679,
#   'ff_alpha': 0.0032,
#   'betas': {'Rm-Rf': 1.1404, 'SMB': 0.0681, 'HML': 0.0252},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.914
#   Model:                             OLS   Adj. R-squared:                  0.914
#   Method:                  Least Squares   F-statistic:                     1262.
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           7.60e-65
#   Time:                         11:00:55   Log-Likelihood:                 329.91
#   No. Observations:                  120   AIC:                            -655.8
#   Df Residuals:                      118   BIC:                            -650.3
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0016      0.001      1.115      0.267      -0.001       0.004
#   Market Excess Return     1.1679      0.033     35.518      0.000       1.103       1.233
#   ==============================================================================
#   Omnibus:                        4.009   Durbin-Watson:                   2.054
#   Prob(Omnibus):                  0.135   Jarque-Bera (JB):                4.472
#   Skew:                           0.149   Prob(JB):                        0.107
#   Kurtosis:                       3.897   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.912
#   Model:                             OLS   Adj. R-squared:                  0.909
#   Method:                  Least Squares   F-statistic:                     398.7
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           6.50e-61
#   Time:                         11:00:55   Log-Likelihood:                 327.93
#   No. Observations:                  120   AIC:                            -647.9
#   Df Residuals:                      116   BIC:                            -636.7
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0032      0.001      2.148      0.034       0.000       0.006
#   Rm-Rf          1.1404      0.040     28.640      0.000       1.061       1.219
#   SMB            0.0681      0.075      0.913      0.363      -0.080       0.216
#   HML            0.0252      0.067      0.377      0.707      -0.107       0.157
#   ==============================================================================
#   Omnibus:                        2.803   Durbin-Watson:                   1.944
#   Prob(Omnibus):                  0.246   Jarque-Bera (JB):                2.636
#   Skew:                           0.113   Prob(JB):                        0.268
#   Kurtosis:                       3.690   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Enrgy': {'capm_alpha': 0.005,
#   'capm_beta': 0.9655,
#   'ff_alpha': 0.0062,
#   'betas': {'Rm-Rf': 1.0285, 'SMB': -0.2821, 'HML': -0.0192},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.478
#   Model:                             OLS   Adj. R-squared:                  0.474
#   Method:                  Least Squares   F-statistic:                     108.2
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           2.22e-18
#   Time:                         11:00:55   Log-Likelihood:                 205.39
#   No. Observations:                  120   AIC:                            -406.8
#   Df Residuals:                      118   BIC:                            -401.2
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0050      0.004      1.242      0.217      -0.003       0.013
#   Market Excess Return     0.9655      0.093     10.403      0.000       0.782       1.149
#   ==============================================================================
#   Omnibus:                        9.504   Durbin-Watson:                   2.220
#   Prob(Omnibus):                  0.009   Jarque-Bera (JB):               17.870
#   Skew:                           0.251   Prob(JB):                     0.000132
#   Kurtosis:                       4.823   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.482
#   Model:                             OLS   Adj. R-squared:                  0.469
#   Method:                  Least Squares   F-statistic:                     35.97
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.65e-16
#   Time:                         11:00:55   Log-Likelihood:                 205.80
#   No. Observations:                  120   AIC:                            -403.6
#   Df Residuals:                      116   BIC:                            -392.5
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0062      0.004      1.528      0.129      -0.002       0.014
#   Rm-Rf          1.0285      0.110      9.336      0.000       0.810       1.247
#   SMB           -0.2821      0.206     -1.368      0.174      -0.691       0.126
#   HML           -0.0192      0.185     -0.104      0.917      -0.385       0.346
#   ==============================================================================
#   Omnibus:                        9.952   Durbin-Watson:                   2.215
#   Prob(Omnibus):                  0.007   Jarque-Bera (JB):               16.167
#   Skew:                           0.353   Prob(JB):                     0.000309
#   Kurtosis:                       4.653   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'HiTec': {'capm_alpha': -0.0006,
#   'capm_beta': 1.1324,
#   'ff_alpha': 0.0005,
#   'betas': {'Rm-Rf': 1.1515, 'SMB': 0.3201, 'HML': -0.5599},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.836
#   Model:                             OLS   Adj. R-squared:                  0.835
#   Method:                  Least Squares   F-statistic:                     601.2
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           3.90e-48
#   Time:                         11:00:55   Log-Likelihood:                 289.15
#   No. Observations:                  120   AIC:                            -574.3
#   Df Residuals:                      118   BIC:                            -568.7
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                   -0.0006      0.002     -0.317      0.752      -0.005       0.003
#   Market Excess Return     1.1324      0.046     24.519      0.000       1.041       1.224
#   ==============================================================================
#   Omnibus:                        1.861   Durbin-Watson:                   1.972
#   Prob(Omnibus):                  0.394   Jarque-Bera (JB):                1.367
#   Skew:                           0.227   Prob(JB):                        0.505
#   Kurtosis:                       3.261   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.899
#   Model:                             OLS   Adj. R-squared:                  0.896
#   Method:                  Least Squares   F-statistic:                     343.7
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.58e-57
#   Time:                         11:00:55   Log-Likelihood:                 318.18
#   No. Observations:                  120   AIC:                            -628.4
#   Df Residuals:                      116   BIC:                            -617.2
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0005      0.002      0.342      0.733      -0.003       0.004
#   Rm-Rf          1.1515      0.043     26.664      0.000       1.066       1.237
#   SMB            0.3201      0.081      3.960      0.000       0.160       0.480
#   HML           -0.5599      0.072     -7.741      0.000      -0.703      -0.417
#   ==============================================================================
#   Omnibus:                        0.228   Durbin-Watson:                   1.971
#   Prob(Omnibus):                  0.892   Jarque-Bera (JB):                0.286
#   Skew:                          -0.101   Prob(JB):                        0.867
#   Kurtosis:                       2.873   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Telcm': {'capm_alpha': 0.0019,
#   'capm_beta': 0.9017,
#   'ff_alpha': 0.0031,
#   'betas': {'Rm-Rf': 0.922, 'SMB': -0.0859, 'HML': -0.0146},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.774
#   Model:                             OLS   Adj. R-squared:                  0.772
#   Method:                  Least Squares   F-statistic:                     403.8
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           6.70e-40
#   Time:                         11:00:55   Log-Likelihood:                 292.61
#   No. Observations:                  120   AIC:                            -581.2
#   Df Residuals:                      118   BIC:                            -575.6
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0019      0.002      0.989      0.325      -0.002       0.006
#   Market Excess Return     0.9017      0.045     20.096      0.000       0.813       0.991
#   ==============================================================================
#   Omnibus:                        1.779   Durbin-Watson:                   2.059
#   Prob(Omnibus):                  0.411   Jarque-Bera (JB):                1.394
#   Skew:                          -0.047   Prob(JB):                        0.498
#   Kurtosis:                       2.480   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.776
#   Model:                             OLS   Adj. R-squared:                  0.770
#   Method:                  Least Squares   F-statistic:                     133.8
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.66e-37
#   Time:                         11:00:55   Log-Likelihood:                 293.12
#   No. Observations:                  120   AIC:                            -578.2
#   Df Residuals:                      116   BIC:                            -567.1
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0031      0.002      1.562      0.121      -0.001       0.007
#   Rm-Rf          0.9220      0.053     17.326      0.000       0.817       1.027
#   SMB           -0.0859      0.100     -0.862      0.391      -0.283       0.111
#   HML           -0.0146      0.089     -0.164      0.870      -0.191       0.162
#   ==============================================================================
#   Omnibus:                        1.757   Durbin-Watson:                   2.079
#   Prob(Omnibus):                  0.415   Jarque-Bera (JB):                1.394
#   Skew:                          -0.059   Prob(JB):                        0.498
#   Kurtosis:                       2.485   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Shops': {'capm_alpha': 0.0027,
#   'capm_beta': 0.8295,
#   'ff_alpha': 0.0039,
#   'betas': {'Rm-Rf': 0.7671, 'SMB': 0.2778, 'HML': -0.0298},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.770
#   Model:                             OLS   Adj. R-squared:                  0.768
#   Method:                  Least Squares   F-statistic:                     394.1
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           2.05e-39
#   Time:                         11:00:55   Log-Likelihood:                 301.16
#   No. Observations:                  120   AIC:                            -598.3
#   Df Residuals:                      118   BIC:                            -592.7
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0027      0.002      1.498      0.137      -0.001       0.006
#   Market Excess Return     0.8295      0.042     19.851      0.000       0.747       0.912
#   ==============================================================================
#   Omnibus:                        2.279   Durbin-Watson:                   2.069
#   Prob(Omnibus):                  0.320   Jarque-Bera (JB):                1.756
#   Skew:                          -0.200   Prob(JB):                        0.416
#   Kurtosis:                       3.438   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.791
#   Model:                             OLS   Adj. R-squared:                  0.786
#   Method:                  Least Squares   F-statistic:                     146.7
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           2.54e-39
#   Time:                         11:00:55   Log-Likelihood:                 307.14
#   No. Observations:                  120   AIC:                            -606.3
#   Df Residuals:                      116   BIC:                            -595.1
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0039      0.002      2.207      0.029       0.000       0.007
#   Rm-Rf          0.7671      0.047     16.200      0.000       0.673       0.861
#   SMB            0.2778      0.089      3.134      0.002       0.102       0.453
#   HML           -0.0298      0.079     -0.376      0.708      -0.187       0.127
#   ==============================================================================
#   Omnibus:                        0.225   Durbin-Watson:                   2.151
#   Prob(Omnibus):                  0.894   Jarque-Bera (JB):                0.035
#   Skew:                          -0.023   Prob(JB):                        0.982
#   Kurtosis:                       3.070   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Hlth': {'capm_alpha': 0.0024,
#   'capm_beta': 0.6759,
#   'ff_alpha': 0.0031,
#   'betas': {'Rm-Rf': 0.7501, 'SMB': -0.2085, 'HML': -0.1358},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.597
#   Model:                             OLS   Adj. R-squared:                  0.594
#   Method:                  Least Squares   F-statistic:                     175.1
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           4.60e-25
#   Time:                         11:00:55   Log-Likelihood:                 277.06
#   No. Observations:                  120   AIC:                            -550.1
#   Df Residuals:                      118   BIC:                            -544.5
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0024      0.002      1.060      0.291      -0.002       0.007
#   Market Excess Return     0.6759      0.051     13.232      0.000       0.575       0.777
#   ==============================================================================
#   Omnibus:                        1.264   Durbin-Watson:                   2.093
#   Prob(Omnibus):                  0.531   Jarque-Bera (JB):                0.800
#   Skew:                           0.129   Prob(JB):                        0.670
#   Kurtosis:                       3.305   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.619
#   Model:                             OLS   Adj. R-squared:                  0.609
#   Method:                  Least Squares   F-statistic:                     62.80
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           3.42e-24
#   Time:                         11:00:55   Log-Likelihood:                 280.36
#   No. Observations:                  120   AIC:                            -552.7
#   Df Residuals:                      116   BIC:                            -541.6
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0031      0.002      1.409      0.162      -0.001       0.007
#   Rm-Rf          0.7501      0.059     12.673      0.000       0.633       0.867
#   SMB           -0.2085      0.111     -1.882      0.062      -0.428       0.011
#   HML           -0.1358      0.099     -1.370      0.173      -0.332       0.061
#   ==============================================================================
#   Omnibus:                        3.430   Durbin-Watson:                   2.027
#   Prob(Omnibus):                  0.180   Jarque-Bera (JB):                2.968
#   Skew:                           0.261   Prob(JB):                        0.227
#   Kurtosis:                       3.568   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Utils': {'capm_alpha': 0.0045,
#   'capm_beta': 0.537,
#   'ff_alpha': 0.005,
#   'betas': {'Rm-Rf': 0.632, 'SMB': -0.3957, 'HML': -0.021},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.400
#   Model:                             OLS   Adj. R-squared:                  0.394
#   Method:                  Least Squares   F-statistic:                     78.52
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           9.75e-15
#   Time:                         11:00:55   Log-Likelihood:                 256.55
#   No. Observations:                  120   AIC:                            -509.1
#   Df Residuals:                      118   BIC:                            -503.5
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                    0.0045      0.003      1.683      0.095      -0.001       0.010
#   Market Excess Return     0.5370      0.061      8.861      0.000       0.417       0.657
#   ==============================================================================
#   Omnibus:                       14.683   Durbin-Watson:                   1.931
#   Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.049
#   Skew:                          -0.845   Prob(JB):                     0.000327
#   Kurtosis:                       3.593   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.441
#   Model:                             OLS   Adj. R-squared:                  0.426
#   Method:                  Least Squares   F-statistic:                     30.50
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.31e-14
#   Time:                         11:00:55   Log-Likelihood:                 260.83
#   No. Observations:                  120   AIC:                            -513.7
#   Df Residuals:                      116   BIC:                            -502.5
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const          0.0050      0.003      1.958      0.053   -5.77e-05       0.010
#   Rm-Rf          0.6320      0.070      9.074      0.000       0.494       0.770
#   SMB           -0.3957      0.130     -3.035      0.003      -0.654      -0.137
#   HML           -0.0210      0.117     -0.180      0.858      -0.252       0.210
#   ==============================================================================
#   Omnibus:                        8.827   Durbin-Watson:                   1.956
#   Prob(Omnibus):                  0.012   Jarque-Bera (JB):                8.603
#   Skew:                          -0.610   Prob(JB):                       0.0135
#   Kurtosis:                       3.481   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """},
#  'Other': {'capm_alpha': -0.0039,
#   'capm_beta': 1.207,
#   'ff_alpha': -0.002,
#   'betas': {'Rm-Rf': 1.1196, 'SMB': -0.0753, 'HML': 0.5536},
#   'capm_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.882
#   Model:                             OLS   Adj. R-squared:                  0.881
#   Method:                  Least Squares   F-statistic:                     881.9
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           1.37e-56
#   Time:                         11:00:55   Log-Likelihood:                 304.48
#   No. Observations:                  120   AIC:                            -605.0
#   Df Residuals:                      118   BIC:                            -599.4
#   Df Model:                            1
#   Covariance Type:             nonrobust
#   ========================================================================================
#                              coef    std err          t      P>|t|      [0.025      0.975]
#   ----------------------------------------------------------------------------------------
#   const                   -0.0039      0.002     -2.178      0.031      -0.007      -0.000
#   Market Excess Return     1.2070      0.041     29.697      0.000       1.127       1.287
#   ==============================================================================
#   Omnibus:                       11.032   Durbin-Watson:                   2.033
#   Prob(Omnibus):                  0.004   Jarque-Bera (JB):               28.438
#   Skew:                           0.109   Prob(JB):                     6.68e-07
#   Kurtosis:                       5.375   Cond. No.                         23.1
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """,
#   'multi_factor_model_summary': <class 'statsmodels.iolib.summary.Summary'>
#   """
#                                OLS Regression Results
#   ===============================================================================
#   Dep. Variable:     Asset Excess Return   R-squared:                       0.929
#   Model:                             OLS   Adj. R-squared:                  0.927
#   Method:                  Least Squares   F-statistic:                     504.7
#   Date:                 Thu, 14 Nov 2024   Prob (F-statistic):           2.24e-66
#   Time:                         11:00:55   Log-Likelihood:                 334.84
#   No. Observations:                  120   AIC:                            -661.7
#   Df Residuals:                      116   BIC:                            -650.5
#   Df Model:                            3
#   Covariance Type:             nonrobust
#   ==============================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
#   ------------------------------------------------------------------------------
#   const         -0.0020      0.001     -1.416      0.159      -0.005       0.001
#   Rm-Rf          1.1196      0.038     29.785      0.000       1.045       1.194
#   SMB           -0.0753      0.070     -1.070      0.287      -0.215       0.064
#   HML            0.5536      0.063      8.794      0.000       0.429       0.678
#   ==============================================================================
#   Omnibus:                        2.810   Durbin-Watson:                   2.200
#   Prob(Omnibus):                  0.245   Jarque-Bera (JB):                2.818
#   Skew:                          -0.020   Prob(JB):                        0.244
#   Kurtosis:                       3.750   Cond. No.                         52.8
#   ==============================================================================
#
#   Notes:
#   [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#   """}}

# %% [markdown]
# ### 2.2. Get the coefficients

# %%
# 3. Get the coefficients of the factor models, including those of CAPM
def factor_model_coeff(results):
    """
    Extract and organize the CAPM alpha/beta and multi-factor alpha/betas from the multi-factor model results.
    
    Parameters:
    - results: The dictionary of multi-factor model results returned by `factor_model_mult`.
    
    Returns:
    - pd.DataFrame: A DataFrame with CAPM alpha/beta, multi-factor alpha, and beta values for each asset and factor.
    """
    # Initialize a list to store each asset's coefficients
    coefficients = []
    
    # Iterate through the results dictionary to extract CAPM alpha/beta and multi-factor alpha/betas
    for asset, result in results.items():
        # Start with the asset's CAPM and multi-factor alpha and beta
        asset_data = {
            'Asset': asset,
            'CAPM_Alpha': result['capm_alpha'],
            'CAPM_Beta': result['capm_beta'],
            'FF_Alpha': result['ff_alpha']
        }
        
        # Add each factor's beta value to the dictionary
        for factor, beta in result['betas'].items():
            asset_data[f'{factor.upper()}_Coefficients'] = beta
        
        # Append the asset's coefficient data to the list
        coefficients.append(asset_data)
    
    # Convert the list of dictionaries to a DataFrame
    coefficients_df = pd.DataFrame(coefficients).set_index('Asset')
    
    return coefficients_df

# %%
ff_3_coeff = factor_model_coeff(ff_3_model)
ff_3_coeff
# Out:
#        CAPM_Alpha  CAPM_Beta  FF_Alpha  RM-RF_Coefficients  SMB_Coefficients  \
# Asset
# NoDur      0.0037     0.6537    0.0045              0.7108           -0.2314
# Durbl     -0.0042     1.6494   -0.0017              1.4418            0.6515
# Manuf      0.0016     1.1679    0.0032              1.1404            0.0681
# Enrgy      0.0050     0.9655    0.0062              1.0285           -0.2821
# HiTec     -0.0006     1.1324    0.0005              1.1515            0.3201
# Telcm      0.0019     0.9017    0.0031              0.9220           -0.0859
# Shops      0.0027     0.8295    0.0039              0.7671            0.2778
# Hlth       0.0024     0.6759    0.0031              0.7501           -0.2085
# Utils      0.0045     0.5370    0.0050              0.6320           -0.3957
# Other     -0.0039     1.2070   -0.0020              1.1196           -0.0753
#
#        HML_Coefficients
# Asset
# NoDur           -0.0202
# Durbl            0.2507
# Manuf            0.0252
# Enrgy           -0.0192
# HiTec           -0.5599
# Telcm           -0.0146
# Shops           -0.0298
# Hlth            -0.1358
# Utils           -0.0210
# Other            0.5536

# %% [markdown]
# * My gmail is binhnguyen.ibm@gmail.com
# * For advance and complex models in practice, we can discuss for collaboration.
# * Thank you.
